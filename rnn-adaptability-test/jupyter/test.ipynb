# %%
import tensorflow as tf
import numpy as np

print(tf.__version__)
print(np.__version__)
# Out:
# 2.10.0
# 1.26.3

# %%
td = np.load("npy/train_datas.npy")
print(td.shape)
tid = np.load("npy/train_input_datas.npy")
print(tid.shape)
# Out:
# (1800, 20, 4)
# (1800, 20)

# %%
from matplotlib import pyplot

pyplot.plot(tid[0], label="td")
pyplot.xticks(np.arange(len(tid[0])))
pyplot.show()

# %%
for mm in np.arange(0,1):
    print(mm)
# Out:
# 0
